# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\axhay\\Downloads\\insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler , LabelEncoder

# %%
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
# ms = MinMaxScaler()
# df[['bmi','charges']]= ms.fit_transform(df[['bmi','charges']])
# df

# %%
x = df.drop(columns = ['charges'])
y= df['charges']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2 , random_state = 42 )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2 , random_state = 42 , dtypes=np.int32)
#
# TypeError: train_test_split() got an unexpected keyword argument 'dtypes'

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7833463107364538

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
age= int(input("enter age:"))
sex= int(input("enter sex:"))
bmi= int(input("enter bmi:"))
children= int(input("enter children:"))
smoker= int(input("enter smoker:"))
region= int(input("enter region:"))
# Out:
# enter age:1
# enter sex:1
# enter bmi:2
# enter children:1
# enter smoker:1
# enter region:1

# %%
new_list = np.array([[age, sex, bmi, children, smoker, region]])

# %%
print(len([age, sex, bmi, children, smoker, region]))
# Out:
# 6

# %%
lr.predict(new_list)
# Out:
# C:\Users\axhay\anaconda3\envs\tensorflow\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([12764.8465077])

# %% [markdown]
# # deep learning

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\axhay\\Downloads\\insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler , LabelEncoder

# %%
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

# %%
import tensorflow as tf
model= tf.keras.Sequential([
    tf.keras.layers.Dense(32, input_shape = (6,),activation= 'relu'),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'linear')
])

# %%
model.compile(optimizer = 'adam' , loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50 , batch_size = 32 , verbose = 1)
# Out:
# Epoch 1/50
# 34/34 [==============================] - 0s 2ms/step - loss: 322066016.0000
# Epoch 2/50
# 34/34 [==============================] - 0s 1ms/step - loss: 320351776.0000
# Epoch 3/50
# 34/34 [==============================] - 0s 1ms/step - loss: 316928896.0000
# Epoch 4/50
# 34/34 [==============================] - 0s 1ms/step - loss: 310089152.0000
# Epoch 5/50
# 34/34 [==============================] - 0s 1ms/step - loss: 297952032.0000
# Epoch 6/50
# 34/34 [==============================] - 0s 1ms/step - loss: 279159328.0000
# Epoch 7/50
# 34/34 [==============================] - 0s 1ms/step - loss: 253743792.0000
# Epoch 8/50
# 34/34 [==============================] - 0s 1ms/step - loss: 223727664.0000
# Epoch 9/50
# 34/34 [==============================] - 0s 1ms/step - loss: 193016352.0000
# Epoch 10/50
# 34/34 [==============================] - 0s 1ms/step - loss: 166540976.0000
# Epoch 11/50
# ...

# %%
y_pred=model.predict(x_test)
# Out:
# 9/9 [==============================] - 0s 0s/step

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 129521235.38221006
